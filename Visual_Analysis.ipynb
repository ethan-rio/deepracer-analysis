# %% [markdown]
# # Visual Analysis
#
# This notebook has been created to support two main purposes:
# * Based on an input image and a set of models, display the action-space probability distribution.
# * Based on an input image and a set of models, visualize which parts of the image the model looks at.
#
# ## Usage
#
# The workbook requires the following:
# * A set of raw images captured from the front camera of the car
# * One or more static model files (`model_*.pb`)
# * The `model_metadata.json`
#
# ## Contributions
#
# As usual, your ideas are very welcome and encouraged so if you have any suggestions either bring them to [the AWS DeepRacer Community](http://join.deepracing.io) or share as code contributions.
#
# ## Requirements
#
# Before you start using the notebook, you will need to install some dependencies. If you haven't yet done so, have a look at [The README.md file](/edit/README.md#running-the-notebooks) to find what you need to install.
#
# This workbook will require `tensorflow` and `cv2` to work.
#
# ## Imports
#
# Run the imports block below:

# %%
import json
import os
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2

import tensorflow as tf
from tensorflow.io.gfile import GFile
from deepracer.model import load_session, visualize_gradcam_discrete_ppo, rgb2gray
# Out:
# 2023-03-23 22:43:34.125376: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 22:43:34.412273: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-23 22:43:34.454519: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ethanphan/deepracer/.venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-03-23 22:43:34.454541: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-23 22:43:35.595121: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ethanphan/deepracer/.venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-03-23 22:43:35.595436: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ethanphan/deepracer/.venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-03-23 22:43:35.595448: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Configure and load files
#
# Provide the paths where the image and models are stored. Also define which iterations you would like to review.

# %%
img_selection = 'logs/sample-model/pictures/*.png'
model_path = 'logs/sample-model/model'
iterations = [15, 30, 48]

# %% [markdown]
# Load the model metadata in, and define which sensor is in use.

# %%
with open("{}/model_metadata.json".format(model_path),"r") as jsonin:
    model_metadata=json.load(jsonin)
my_sensor = [sensor for sensor in model_metadata['sensor'] if sensor != "LIDAR"][0]
display(model_metadata)
# Out:
# {'action_space': [{'steering_angle': -30, 'speed': 1.0},
#   {'steering_angle': -20, 'speed': 1.0},
#   {'steering_angle': -20, 'speed': 2.0},
#   {'steering_angle': -10, 'speed': 1.0},
#   {'steering_angle': -10, 'speed': 2.0},
#   {'steering_angle': 0, 'speed': 1.0},
#   {'steering_angle': 0, 'speed': 2.0},
#   {'steering_angle': 10, 'speed': 1.0},
#   {'steering_angle': 10, 'speed': 2.0},
#   {'steering_angle': 20, 'speed': 1.0},
#   {'steering_angle': 20, 'speed': 2.0},
#   {'steering_angle': 30, 'speed': 1.0}],
#  'sensor': ['FRONT_FACING_CAMERA'],
#  'neural_network': 'DEEP_CONVOLUTIONAL_NETWORK_SHALLOW',
#  'training_algorithm': 'clipped_ppo',
#  'action_space_type': 'discrete',
#  'version': '3'}

# %% [markdown]
# Load in the pictures from the pre-defined path.

# %%
picture_files = sorted(glob.glob(img_selection))
display(picture_files)
# Out:
# ['logs/sample-model/pictures/dr-demo-1.png',
#  'logs/sample-model/pictures/dr-demo-2.png',
#  'logs/sample-model/pictures/dr-demo-3.png']

# %%
action_names = []
degree_sign= u'\N{DEGREE SIGN}'
for action in model_metadata['action_space']:
    action_names.append(str(action['steering_angle'])+ degree_sign + " "+"%.1f"%action["speed"])
display(action_names)
# Out:
# ['-30° 1.0',
#  '-20° 1.0',
#  '-20° 2.0',
#  '-10° 1.0',
#  '-10° 2.0',
#  '0° 1.0',
#  '0° 2.0',
#  '10° 1.0',
#  '10° 2.0',
#  '20° 1.0',
#  '20° 2.0',
#  '30° 1.0']

# %% [markdown]
# ## Load the model files and process pictures
# We will now load in the models and process the pictures. Output is a nested list with size `n` models as the outer and `m` picture as the inner list. The inner list will contain a number of values equal to the

# %%
model_inference = []
models_file_path = []

for n in iterations:
    models_file_path.append("{}/model_{}.pb".format(model_path,n))
display(models_file_path)

for model_file in models_file_path:
    model, obs, model_out = load_session(model_file, my_sensor)
    arr = []
    for f in picture_files[:]:
        img = cv2.imread(f)
        img = cv2.resize(img, dsize=(160, 120), interpolation=cv2.INTER_CUBIC)
        img_arr = np.array(img)
        img_arr = rgb2gray(img_arr)
        img_arr = np.expand_dims(img_arr, axis=2)
        current_state = {"observation": img_arr} #(1, 120, 160, 1)
        y_output = model.run(model_out, feed_dict={obs:[img_arr]})[0]
        arr.append (y_output)
        
    model_inference.append(arr)
    model.close()
    tf.compat.v1.reset_default_graph()
# Out:
# ['logs/sample-model/model/model_15.pb',
#  'logs/sample-model/model/model_30.pb',
#  'logs/sample-model/model/model_48.pb']
# Device mapping: no known devices.
# load graph: logs/sample-model/model/model_15.pb
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_3_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_5_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/StopGradient/input: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/StopGradient: (StopGradient): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_1/y: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy: (Softmax): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv_1: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/Conv2D_1: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_1_activation_1: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/Conv2D_1: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_3_activation_1: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/Conv2D_1: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_5_activation_1: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/BatchnormActivationDropout_1_activation_1: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/StopGradient/input_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/StopGradient_1: (StopGradient): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_1/y_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_1_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/add_1: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_1: (Softmax): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_0/FRONT_FACING_CAMERA/FRONT_FACING_CAMERA: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape/1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/sub/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_0/FRONT_FACING_CAMERA/FRONT_FACING_CAMERA_1: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv/y_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub/y_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_1_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_2_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape/1_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/sub/x_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_1_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_2_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.401599: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.407492: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.407541: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.407551: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.407557: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.407565: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.407574: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.407622: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408444: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408456: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408465: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408473: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_3_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408482: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408490: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408500: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408508: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408515: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_5_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408526: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408534: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408542: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408550: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408559: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408567: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408574: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408583: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408590: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408599: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408607: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408615: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/StopGradient/input: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408622: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/StopGradient: (StopGradient): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408629: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408636: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul_1/y: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408643: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408651: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408660: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408668: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408676: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408683: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408690: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408698: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy: (Softmax): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408706: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv_1: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408714: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408760: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408773: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408782: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/Conv2D_1: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408791: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408799: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_1_activation_1: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408808: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408815: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408822: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/Conv2D_1: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408830: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408837: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_3_activation_1: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408845: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408852: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408860: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/Conv2D_1: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408867: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408874: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_5_activation_1: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408884: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408894: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.408902: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.411227: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.412089: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.412274: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413152: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413284: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413330: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/BatchnormActivationDropout_1_activation_1: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413363: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413428: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413480: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/StopGradient/input_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413512: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/StopGradient_1: (StopGradient): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413538: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413565: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul_1/y_1: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413591: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul_1_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413616: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/add_1: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413646: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413674: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413701: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias/read_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413727: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413752: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/BiasAdd_1: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413774: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_1: (Softmax): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413814: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_0/FRONT_FACING_CAMERA/FRONT_FACING_CAMERA: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413842: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413873: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.413977: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414036: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414049: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414060: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414101: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414120: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414694: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414836: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414852: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414864: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape/1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414885: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414896: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414913: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414924: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/sub/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.414937: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415026: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415043: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415058: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415071: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415085: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_0/FRONT_FACING_CAMERA/FRONT_FACING_CAMERA_1: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415097: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv/y_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415108: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub/y_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415119: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415132: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415144: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415156: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415172: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415184: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415201: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415211: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_1_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415219: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_2_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415231: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape/1_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415243: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415253: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415264: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415274: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/sub/x_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415286: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_3: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415339: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_1_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415351: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_2_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415364: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:21.415376: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Device mapping: no known devices.
# load graph: logs/sample-model/model/model_30.pb
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_3_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_5_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/StopGradient/input: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/StopGradient: (StopGradient): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_1/y: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy: (Softmax): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_0/FRONT_FACING_CAMERA/FRONT_FACING_CAMERA: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# 2023-03-17 16:10:25.575214: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575219: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575225: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575231: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575236: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575258: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/StopGradient/input: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575287: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/StopGradient: (StopGradient): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575310: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575324: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul_1/y: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575337: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575350: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575364: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575379: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575392: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575406: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575420: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575433: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy: (Softmax): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575449: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_0/FRONT_FACING_CAMERA/FRONT_FACING_CAMERA: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575462: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575475: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575491: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575504: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575517: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575530: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575543: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575559: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575573: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575587: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575600: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575614: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape/1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575627: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575639: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575652: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575666: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/sub/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575679: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575693: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575707: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575720: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-03-17 16:10:25.575733: I tensorflow/core/common_runtime/placer.cc:114] main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_3_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/BatchnormActivationDropout_5_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/BatchnormActivationDropout_1_activation: (Relu): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/StopGradient/input: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/StopGradient: (StopGradient): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_1/y: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/add: (Add): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy: (Softmax): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_0/FRONT_FACING_CAMERA/FRONT_FACING_CAMERA: (Placeholder): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/truediv/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/sub/y: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_2/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Conv2d_4/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/FRONT_FACING_CAMERA/Flatten/flatten/Reshape/shape/1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/middleware_fc_embedder/Dense_0/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/gradients_from_head_0-0_rescalers: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/sub/x: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/strided_slice/stack_2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/kernel: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# main_level/agent/main/online/network_1/ppo_head_0/policy_fc/bias: (Const): /job:localhost/replica:0/task:0/device:CPU:0

# %% [markdown]
# ## Simulation Image Analysis - Probability distribution on decisions (actions)
#
# We will now show the probabilities per action for the selected picture and iterations. The higher the probability of one single action the more mature is the model. Comparing different models enables the developer to see how the model is becoming more certain over time.

# %%
PICTURE_INDEX=1
display(picture_files[PICTURE_INDEX])
# Out:
# 'logs/sample-model/pictures/dr-demo-2.png'

# %%
x = list(range(1,len(action_names)+1))

num_plots = len(iterations)
fig, ax = plt.subplots(num_plots,1,figsize=(20,3*num_plots),sharex=True,squeeze=False)

for p in range(0, num_plots):
    ax[p][0].bar(x,model_inference[p][PICTURE_INDEX][::-1])
    plt.setp(ax[p, 0], ylabel=os.path.basename(models_file_path[p]))
    
plt.xticks(x,action_names[::-1],rotation='vertical')
plt.show()

# %% [markdown]
# ## What is the model looking at?
#
# Gradcam: visual heatmap of where the model is looking to make its decisions. based on https://arxiv.org/pdf/1610.02391.pdf

# %%
heatmaps = []
view_models = models_file_path[1:3]

for model_file in view_models:
    model, obs, model_out = load_session(model_file, my_sensor)
    arr = []
    for f in picture_files:
        img = cv2.imread(f)
        img = cv2.resize(img, dsize=(160, 120), interpolation=cv2.INTER_CUBIC)
        heatmap = visualize_gradcam_discrete_ppo(model, img, category_index=0, num_of_actions=len(action_names))
        heatmaps.append(heatmap)    

    tf.reset_default_graph()
# Out:
# Device mapping: no known devices.
# load graph: logs/sample-model/model/model_30.pb
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       8     img = cv2.imread(f)
#       9     img = cv2.resize(img, dsize=(160, 120), interpolation=cv2.INTER_CUBIC)
# ---> 10     heatmap = visualize_gradcam_discrete_ppo(model, img, category_index=0, num_of_actions=len(action_names))
#      11     heatmaps.append(heatmap)
#      13 tf.reset_default_graph()
#
# File ~/deepracer/.venv/lib/python3.8/site-packages/deepracer/model/visualization.py:75, in visualize_gradcam_discrete_ppo(sess, rgb_img, sensor, category_index, num_of_actions)
#      72 # Get he policy head for clipped ppo in coach
#      73 model_out_layer = sess.graph.get_tensor_by_name(
#      74     'main_level/agent/main/online/network_1/ppo_head_0/policy:0')
# ---> 75 loss = tf.multiply(model_out_layer, tf.one_hot([category_index], num_of_actions))
#      76 reduced_loss = tf.reduce_sum(loss[0])
#      78 # For front cameras use the below
#
# File ~/deepracer/.venv/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/deepracer/.venv/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# TypeError: <tf.Tensor 'main_level/agent/main/online/network_1/ppo_head_0/policy:0' shape=(None, 12) dtype=float32> is out of scope and cannot be used here. Use return values, explicit Python locals or TensorFlow collections to access it.
# Please see https://www.tensorflow.org/guide/function#all_outputs_of_a_tffunction_must_be_return_values for more information.
#
# <tf.Tensor 'main_level/agent/main/online/network_1/ppo_head_0/policy:0' shape=(None, 12) dtype=float32> was defined here:
# <unknown>
#
# The tensor <tf.Tensor 'main_level/agent/main/online/network_1/ppo_head_0/policy:0' shape=(None, 12) dtype=float32> cannot be accessed from here, because it was defined in <tensorflow.python.framework.ops.Graph object at 0x7f002c63f8b0>, which is out of scope.

# %%
fig, ax = plt.subplots(len(view_models),len(picture_files),
                       figsize=(7*len(view_models),2.5*len(picture_files)), sharex=True, sharey=True, squeeze=False)

for i in list(range(len(view_models))):
    plt.setp(ax[i, 0], ylabel=os.path.basename(view_models[i]))
    for j in list(range(len(picture_files))):
        ax[i][j].imshow(heatmaps[i * len(picture_files) + j])
        plt.setp(ax[-1:, j], xlabel=os.path.basename(picture_files[j]))
       
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 7
#       5     plt.setp(ax[i, 0], ylabel=os.path.basename(view_models[i]))
#       6     for j in list(range(len(picture_files))):
# ----> 7         ax[i][j].imshow(heatmaps[i * len(picture_files) + j])
#       8         plt.setp(ax[-1:, j], xlabel=os.path.basename(picture_files[j]))
#      10 plt.show()
#
# IndexError: list index out of range
